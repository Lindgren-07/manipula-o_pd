# %%
import pandas as pd;
df = pd.read_csv('./2020.02.26 - PLANILHA DO TERMO DE COLABORAÇÃO APAEs - 2020_0.csv',sep=';')

# %%
df
# Out:
#        ORD Nº Processo                       Unidade Gestora  \
# 0      1.0  1213122/18        080261 - DIR.ENS.REGIAO CENTRO
# 1      2.0  1794588/18        080261 - DIR.ENS.REGIAO CENTRO
# 2      3.0    04107/16  080262 - DIR.ENS.REGIAO CENTRO OESTE
# 3      4.0     2909/16    080263 - DIR.ENS.REGIAO CENTRO SUL
# 4      5.0     2911/16    080263 - DIR.ENS.REGIAO CENTRO SUL
# ..     ...         ...                                   ...
# 281  282.0    00861/16           080351 - DIR.ENS.REG. AVARE
# 282  283.0    00862/16           080351 - DIR.ENS.REG. AVARE
# 283  284.0    00863/16           080351 - DIR.ENS.REG. AVARE
# 284  285.0    00560/16       080352 - DIR.ENS.REG. PENAPOLIS
# 285    NaN         NaN                                   NaN
#
#                                         Conveniado    CNPJ da entidade  \
# 0    AUMA-ASSOCIAÇÃO DOS AMIGOS DA CRIANÇA AUTISTA  38.893.038/0001-03
# 1    ASSOC. BRAS. DE ASSIST. E DESENV.SOCIAL-ABADS  60.805.975/0001-19
# ...

# %% [markdown]
# Limpeza de dados

# %%
df['Total de alunos (D.I+T.E.A)'].unique()
# Out:
# array([ 53., 178.,  89.,  42., 193.,  66.,  93.,  59.,  64.,  74.,  44.,
#         77.,  61., 210., 144., 112.,  47.,  57., 161., 358.,  80., 308.,
#        164.,  25., 132.,  35.,  55.,  29.,  54.,  24.,  23., 297., 141.,
#         88.,  69., 167.,   2.,  62.,  34.,  33., 217.,  45.,  41., 123.,
#        136.,  18.,  31.,  40.,  36., 114.,  52.,  50.,  11., 226.,  19.,
#         58.,   7., 116.,  20.,  38., 149.,  26.,  49., 180.,  65., 182.,
#         70.,  84.,  17.,  14., 181.,  39.,  95., 103.,  98., 142.,  37.,
#         21.,  48., 107., 162.,  63.,  90.,  67.,  99.,   5.,  81.,  12.,
#         30.,  43.,  46.,  27.,  13.,  83.,  97., 293., 102., 120., 100.,
#         22.,  51., 108.,  87., 126.,  60., 209., 216.,  86., 146.,  68.,
#        154.,  10.,  71.,  28., 119., 215.,  16.,  76., 101.,  32.,  92.,
#         56., 134., 185., 125., 122.,   0., 127., 176., 147.,  79., 156.,
#        121.,  75.,  nan])

# %%
convertido = pd.to_numeric(df['Total de alunos (D.I+T.E.A)'],errors='coerce')

# %%
convertido.unique()
# Out:
# array([ 53., 178.,  89.,  42., 193.,  66.,  93.,  59.,  64.,  74.,  44.,
df['Qntd. Alunos T.E.A'] = pd.to_numeric(df['Qntd. Alunos T.E.A'],errors='coerce')

# %%
df['Valor total'] = pd.to_numeric(df[' Valor total'], errors='coerce')

# %%
df['Qntd. alunos D.I'] = pd.to_numeric(df['Qntd. alunos D.I'],errors='coerce')

# %%
df['Fim do aditamento'] = pd.to_datetime(df['Fim do aditamento'],errors='coerce')

# %%
df['Início do aditamento'] = pd.to_datetime(df['Início do aditamento'],errors='coerce')

# %%
df
# Out:
#        ORD Nº Processo                       Unidade Gestora  \
# 0      1.0  1213122/18        080261 - DIR.ENS.REGIAO CENTRO
# 1      2.0  1794588/18        080261 - DIR.ENS.REGIAO CENTRO
# 2      3.0    04107/16  080262 - DIR.ENS.REGIAO CENTRO OESTE
# 3      4.0     2909/16    080263 - DIR.ENS.REGIAO CENTRO SUL
# 4      5.0     2911/16    080263 - DIR.ENS.REGIAO CENTRO SUL
# ..     ...         ...                                   ...
# 281  282.0    00861/16           080351 - DIR.ENS.REG. AVARE
# 282  283.0    00862/16           080351 - DIR.ENS.REG. AVARE
# 283  284.0    00863/16           080351 - DIR.ENS.REG. AVARE
# 284  285.0    00560/16       080352 - DIR.ENS.REG. PENAPOLIS
# 285    NaN         NaN                                   NaN
#
#                                         Conveniado    CNPJ da entidade  \
# 0    AUMA-ASSOCIAÇÃO DOS AMIGOS DA CRIANÇA AUTISTA  38.893.038/0001-03
# 1    ASSOC. BRAS. DE ASSIST. E DESENV.SOCIAL-ABADS  60.805.975/0001-19
# ...

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [ORD, Nº Processo, Unidade Gestora, Conveniado, CNPJ da entidade, Status do Termo de Colaboração, Data da celebração , Início do aditamento, Fim do aditamento, Qntd. alunos D.I, Qntd. Alunos T.E.A, Total de alunos (D.I+T.E.A),  Valor total, Valor total]
# Index: []

# %%
dados_limpos = df.dropna()

# %%
dados_limpos
# Out:
# Empty DataFrame
# Columns: [ORD, Nº Processo, Unidade Gestora, Conveniado, CNPJ da entidade, Status do Termo de Colaboração, Data da celebração , Início do aditamento, Fim do aditamento, Qntd. alunos D.I, Qntd. Alunos T.E.A, Total de alunos (D.I+T.E.A),  Valor total, Valor total]
# Index: []

# %%
dados_filtardos = df.describe()

# %%
dados_filtardos.head()
# Out:
#               ORD  Qntd. alunos D.I  Qntd. Alunos T.E.A  \
# count  285.000000        285.000000          285.000000
# mean   143.000000         58.487719            9.701754
# std     82.416625         46.380135           21.546841
# min      1.000000          0.000000            0.000000
# 25%     72.000000         28.000000            0.000000
#
#        Total de alunos (D.I+T.E.A)
# count                   285.000000
# mean                     68.189474
# std                      55.344560
# min                       0.000000
# 25%                      31.000000
